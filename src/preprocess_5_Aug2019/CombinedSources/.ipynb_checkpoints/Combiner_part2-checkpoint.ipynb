# %%
import pandas as pd
import re
import textacy

# %%
fk_df = pd.read_csv('ForestKeywordsProcessed_v1.csv',index_col=0)

# %%
fk_df.head(10)
# Out:
#         genus         species  \
# 0     Abarema         jupunba
# 1      Acacia  auriculiformis
# 2      Acacia         mangium
# 3       Adina      cordifolia
# 4       Adina    microcephala
# 5  Afrormosia           elata
# 6     Afzelia        africana
# 7     Afzelia           bella
# 8     Afzelia     bipindensis
# 9     Afzelia      cuanzensis
#
#                                          common_name  \
# 0                        Ingarana;Tento Azul;Huruasa
# 1  Black Wattle;Brown Salwood;Mangge Hutan;Tongke...
# 2  Black Wattle;Brown Salwood;Mangge Hutan;Tongke...
# 3  Khvao;Kwao;Haldu;Lasi;Thom;Meraga;Hnaw;Adina;H...
# 4                   Matumi;Rhodesian Redwood;Mugonha
# 5  Obang;Obang;Assamela;Kokrodua;Ole;Bohala;Mohol...
# 6  N’kokongo Uvala;M’Banga;Doussié;N’Kokongo;Ling...
# 7  N’kokongo Uvala;M’Banga;Doussié;N’Kokongo;Ling...
# 8  N’kokongo Uvala;M’Banga;Doussié;N’Kokongo;Ling...
# 9  N’kokongo Uvala;M’Banga;Doussié;N’Kokongo;Ling...
#
#                                          range_state
# 0                                                 GY
# 1                               AU;ID;MY;PG;TH;GB;US
# 2                               AU;ID;MY;PG;TH;GB;US
# 3                      KH;IN;ID;LA;MY;MM;PH;LK;TH;VN
# 4  DZ;ES;ES;EG;LY;PT;ES;MA;SD;TN;EH;BI;KM;DJ;ER;E...
# 5                                  CM;CF;CI;GH;CD;FR
# 6       AO;CM;CG;CI;GH;MZ;NG;SN;SL;TZ;CD;DE;PT;GB;US
# 7       AO;CM;CG;CI;GH;MZ;NG;SN;SL;TZ;CD;DE;PT;GB;US
# 8       AO;CM;CG;CI;GH;MZ;NG;SN;SL;TZ;CD;DE;PT;GB;US
# 9       AO;CM;CG;CI;GH;MZ;NG;SN;SL;TZ;CD;DE;PT;GB;US

# %%
base_df = pd.read_csv('combined_species_3.csv',index_col=0)
base_df.head(10)
# Out:
#   family    genus        species sub_sp      common_name range_state  \
# 0    NaN  Abarema       abbottii    NaN              NaN         NaN
# 1    NaN  Abarema      alexandri    NaN              NaN         NaN
# 2    NaN  Abarema       bigemina    NaN              NaN         NaN
# 3    NaN  Abarema     callejasii    NaN              NaN         NaN
# 4    NaN  Abarema     centiflora    NaN              NaN         NaN
# 5    NaN  Abarema      cochleata    NaN              NaN         NaN
# 6    NaN  Abarema  cochliocarpos    NaN              NaN         NaN
# 7    NaN  Abarema      commutata    NaN              NaN         NaN
# 8    NaN  Abarema     curvicarpa    NaN  orelha de negro         NaN
# 9    NaN  Abarema    filamentosa    NaN              NaN         NaN
#
#    is_tropical  is_coniferous  flag
# 0          NaN            NaN   1.0
# 1          NaN            NaN   0.0
# 2          NaN            NaN   1.0
# 3          NaN            NaN   1.0
# 4          NaN            NaN   1.0
# 5          NaN            NaN   1.0
# 6          NaN            NaN   0.0
# 7          NaN            NaN   0.0
# 8          NaN            NaN   0.0
# 9          NaN            NaN   1.0

# %%
#Merge 

for i, row in fk_df.iterrows():
    gn = row['genus']
    sp = row['species']
    
    # find in base_df
    idx = base_df.loc[( base_df['genus'] == gn ) & (base_df['species'] == sp)].index.tolist()
    if len(idx) == 0 :
        
        cn = row['common_name']
        if type(cn) == str :
            cn = cn.lower()
        else:
            cn = None
        #insert into base_df
        tmp_dict = {
            'family'  : None,
            'genus' : gn ,
            'species' : sp,
            'sub_sp' : None,
            'common_name' : cn,
            'range_state': row['range_state'],
            'is_tropical' : 1,
            'is_coniferous': None,
            'flag' : 0,
        }
        base_df = base_df.append(tmp_dict,ignore_index=True)
    else :
        idx = idx[0]
        # merge
        cn0 = base_df.loc[idx,'common_name']
        rs0 = base_df.loc[idx,'range_state']
        
        cn1  = row['common_name']
        rs1  = row['range_state']
        
        if type(cn0) != str :
            cn0 = []
        else:
            cn0 = cn0.lower()
            cn0 = cn0.split(';')
            
        if type(cn1) != str :
            cn1 = []
        else :
            cn1 = cn1.lower()
            cn1 = cn.split(';')
        
        cn0.extend(cn1)
        cn = list(set(cn0))
# Out:
# []
# [121]
# [183]
# []
# []
# []
# [633]
# [634]
# [635]
# []
# [636]
# []
# [845]
# []
# []
# []
# [855]
# [859]
# []
# [872]
# [879]
# [892]
# []
# [922]
# [1167]
# [1170]
# [1172]
# []
# [1174]
# [1177]
# [1180]
# [1181]
# [1214]
# []
# [1220]
# []
# [1315]
# []
# [1343]
# [1351]
# []
# [1391]
# []
# []
# []
# []
# [1423]
# []
# []
# []
# []
# [1451]
# [1452]
# [1454]
# [1455]
# []
# [1459]
# []
# []
# [1509]
# []
# []
# []
# [1674]
# [1675]
# []
# []
# [1695]
# [1696]
# []
# []
# []
# []
# []
# [2406]
# [2408]
# [2458]
# [2483]
# [2563]
# [2566]
# [2567]
# [2577]
# [2614]
# []
# [2699]
# []
# []
# []
# [2840]
# [2842]
# []
# []
# []
# [2928]
# [2930]
# [2936]
# []
# [2950]
# [3149]
# [3150]
# [3151]
# [3192]
# [3193]
# []
# []
# []
# []
# []
# [3250]
# [3268]
# []
# []
# [3292]
# [3293]
# [3295]
# [3296]
# [3297]
# [3298]
# []
# [3301]
# [3302]
# []
# []
# [3393]
# [3396]
# [3397]
# [3399]
# []
# []
# [3471]
# [3511]
# [3532]
# [3573]
# []
# []
# [3625]
# []
# [3827]
# []
# [3892]
# []
# [4054]
# [4110]
# []
# []
# []
# [4155]
# [4156]
# [4158]
# []
# []
# []
# [4382]
# [4384]
# [4388]
# [4460]
# []
# []
# []
# [4514]
# []
# []
# [4558]
# [4575]
# [4576]
# [4577]
# [4578]
# []
# []
# [4585]
# [4587]
# []
# [4589]
# []
# []
# []
# [4598]
# []
# [4603]
# []
# []
# [4731]
# [4967]
# []
# []
# []
# [4996]
# []
# []
# [5038]
# [5044]
# [5046]
# [5052]
# [5054]
# [5057]
# []
# []
# []
# [5190]
# [5193]
# []
# [5226]
# [5227]
# [5390]
# [5516]
# []
# []
# [5646]
# []
# []
# [5650]
# [5651]
# []
# []
# [5676]
# [5692]
