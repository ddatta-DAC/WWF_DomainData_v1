# %% [markdown]
# Format the file combined_species file
# -----
#
# Input file : combined_species_1.csv

# %%
import pandas as pd
import textacy
import re

# %%
base_inp_file ='combined_species_1.csv'
base_df = pd.read_csv(base_inp_file,index_col=0)

# %%
def setup_locs_list():
        loc_list_file = 'country_list.txt'
        locs = []

        f = open(loc_list_file,'r') 
        with open(loc_list_file,'r')  as f:
            content = f.readlines()
            # you may also want to remove whitespace characters like `\n` at the end of each line
            locs = [x.strip() for x in content] 

        locs = [ l.lower() for l in locs]
        return locs
    
locs = setup_locs_list()

def check_location(token):
    global locs
    if token.lower() in locs :
        return True
    return False
    
def clean_cn_aux(cn):
    res = []
    try :
        st = cn.index('(')
        if st is not None :
            if '(' in cn :
                en = cn.index(')')
            else :
                en =-1
            inp = cn[st+1:en]
            inp = textacy.preprocess.normalize_whitespace(inp)
            inp = inp.split(',')

            fp  = cn[0:st]
            fp = fp.strip()
            
            for r in inp:
                r = r.strip()
                res.append(r)
            res.append(fp)

    except :
        res = [cn]
    res_1 = []
    for r in res:
        if check_location(r) == False:
            res_1.append(r)
    return res_1 


# ------------------------------------ #
def clean_up_common_names(row):
    if type(row['common_name']) != str :
        return None
    
    common_names = row['common_name'].lower()
    common_names = common_names.split(';')
    res = []
    for _s in common_names :
        _s = _s.replace('"','')
        _s = _s.replace('`','')
        tmp = clean_cn_aux(_s)
        res.extend(tmp)
    res = [t.strip() for t in res]
    res = ';'.join(res)
    return res

base_df['common_name'] = base_df.apply(clean_up_common_names,axis=1)

# %%
base_df.head(10)
base_df['is_tropical'] = None

def set_genus(row):
    scn = row['sc_name']
    gn = scn.split(' ')[0]
    return gn

base_df['genus'] = base_df.apply(set_genus,axis=1)

# %% [markdown]
# All genus with coniferous plants will have conifers only
# ----------

# %%
def find_con_genus(df) :
    genus_list = []
    for i,row in df.iterrows():
        if row['is_coniferous'] == 1: 
            gn = row['genus']
            genus_list.append(gn)
    genus_list = list(set(genus_list))
    return genus_list
 

con_genus_list = find_con_genus(base_df)

def rectify_coniferous(row):
    global con_genus_list
    gn = row['genus']
    if gn in con_genus_list:
        return 1
    return row['is_coniferous']

base_df['is_coniferous'] = base_df.apply(rectify_coniferous,axis =1)

# %%
def set_species(row):
    scn = row['sc_name'] 
    scn = scn.split(' ')
    if len(scn) == 1 :
        return None
    elif len(scn) >= 2 :
        return scn[1]

def set_subsp(row):
    scn = row['sc_name'] 
    scn = scn.split(' ')
    if len(scn) <= 2 :
        return None
    else :
        return scn[2]

base_df['species'] = None
base_df['sub_sp'] = None
base_df['species'] = base_df.apply(set_species,axis = 1)
base_df['sub_sp'] = base_df.apply(set_subsp,axis = 1)

base_df.to_csv('combined_species_2.csv')

# %%
print (base_df.columns)
base_df.head(10)
# Out:
# Index(['entity_id', 'is_coniferous', 'sc_name', 'family', 'flag',
#        'range_state', 'common_name', 'genus', 'is_tropical', 'species',
#        'sub_sp'],
#       dtype='object')
#    entity_id  is_coniferous                sc_name       family  flag  \
# 0          1            0.0  Acacia auriculiformis  Leguminosae   0.0
# 1          2            0.0     Acacia crassicarpa  Leguminosae   1.0
# 2          3            0.0       Acacia decurrens  Leguminosae   NaN
# 3          4            0.0             Acacia koa  Leguminosae   0.0
# 4          5            0.0         Acacia mangium  Leguminosae   NaN
# 5          6            0.0        Acacia mearnsii  Leguminosae   NaN
# 6          7            0.0     Acacia melanoxylon  Leguminosae   NaN
# 7          8            0.0        Acacia nilotica  Leguminosae   0.0
# 8          9            0.0       Acacia pubescens  Leguminosae   NaN
# 9         10            0.0         Acer campestre  Sapindaceae   0.0
#
#   range_state      common_name   genus is_tropical         species sub_sp
# 0         NaN  ear-leaf acacia  Acacia        None  auriculiformis   None
# 1         NaN             None  Acacia        None     crassicarpa   None
# 2         NaN             None  Acacia        None       decurrens   None
# 3         NaN     koa;gray koa  Acacia        None             koa   None
# 4         NaN             None  Acacia        None         mangium   None
# 5         NaN             None  Acacia        None        mearnsii   None
# 6         NaN             None  Acacia        None     melanoxylon   None
# 7         NaN       sunt;qarad  Acacia        None        nilotica   None
# 8         NaN             None  Acacia        None       pubescens   None
# 9         NaN      field maple    Acer        None       campestre   None

# %%
#Reorderthe columns
base_df = base_df[['entity_id',
                    'sc_name',
                    'family',
                    'genus',
                    'species',
                    'sub_sp' ,
                    'common_name',
                    'range_state',
                    'is_tropical',
                    'is_coniferous',
                    'flag']]
base_df = base_df.sort_values(by = ['genus','species','sub_sp'])

base_df.to_csv('combined_species_2.csv')
base_df.head(10)
# Out:
#        entity_id                sc_name family    genus        species sub_sp  \
# 24562      24563       Abarema abbottii    NaN  Abarema       abbottii   None
# 24560      24561      Abarema alexandri    NaN  Abarema      alexandri   None
# 18069      18070       Abarema bigemina    NaN  Abarema       bigemina   None
# 24552      24553     Abarema callejasii    NaN  Abarema     callejasii   None
# 24566      24567     Abarema centiflora    NaN  Abarema     centiflora   None
# 24550      24551      Abarema cochleata    NaN  Abarema      cochleata   None
# 24559      24560  Abarema cochliocarpos    NaN  Abarema  cochliocarpos   None
# 24547      24548      Abarema commutata    NaN  Abarema      commutata   None
# 24543      24544     Abarema curvicarpa    NaN  Abarema     curvicarpa   None
# 24557      24558    Abarema filamentosa    NaN  Abarema    filamentosa   None
#
#            common_name range_state is_tropical  is_coniferous  flag
# 24562             None         NaN        None            NaN   1.0
# 24560             None         NaN        None            NaN   0.0
# 18069             None         NaN        None            NaN   1.0
# 24552             None         NaN        None            NaN   1.0
# 24566             None         NaN        None            NaN   1.0
# 24550             None         NaN        None            NaN   1.0
# 24559             None         NaN        None            NaN   0.0
# 24547             None         NaN        None            NaN   0.0
# 24543  orelha de negro         NaN        None            NaN   0.0
# 24557             None         NaN        None            NaN   1.0

# %%
import pandas as pd
base_df = pd.read_csv('combined_species_2.csv',index_col=0)


# Start Depuplication!
# Out:
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id                        sc_name    family  genus      species  \
# 22207      22208  Abies chensiensis chensiensis  Pinaceae  Abies  chensiensis
#
#             sub_sp                         common_name range_state  \
# 22207  chensiensis  秦岭冷杉;qin ling leng shan;shensi fir         NaN
#
#        is_tropical  is_coniferous  flag
# 22207          NaN            1.0   0.0
#        entity_id                         sc_name    family  genus  \
# 32653      32654  Abies chensiensis salouenensis  Pinaceae  Abies
#
#            species        sub_sp  common_name range_state  is_tropical  \
# 32653  chensiensis  salouenensis  salween fir         NaN          NaN
#
#        is_coniferous  flag
# 32653            1.0   0.0
#        entity_id                               sc_name    family  genus  \
# 22209      22210  Abies chensiensis yulongxueshanensis  Pinaceae  Abies
#
#            species              sub_sp common_name range_state  is_tropical  \
# 22209  chensiensis  yulongxueshanensis         NaN         NaN          NaN
#
#        is_coniferous  flag
# 22209            1.0   0.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id                  sc_name    family  genus   species  \
# 33622      33623  Abies cilicica cilicica  Pinaceae  Abies  cilicica
#
#          sub_sp common_name range_state  is_tropical  is_coniferous  flag
# 33622  cilicica         NaN         NaN          NaN            1.0   1.0
#        entity_id                  sc_name    family  genus   species  \
# 21255      21256  Abies cilicica isaurica  Pinaceae  Abies  cilicica
#
#          sub_sp common_name range_state  is_tropical  is_coniferous  flag
# 21255  isaurica         NaN         NaN          NaN            1.0   1.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id                       sc_name    family  genus   species  \
# 29247      29248  Abies delavayi fansipanensis  Pinaceae  Abies  delavayi
#
#               sub_sp   common_name range_state  is_tropical  is_coniferous  \
# 29247  fansipanensis  fansipan fir         NaN          NaN            1.0
#
#        flag
# 29247   1.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id            sc_name    family  genus species sub_sp  \
# 32656      32657  Abies fabri fabri  Pinaceae  Abies   fabri  fabri
#
#                              common_name range_state  is_tropical  \
# 32656  冷杉;pao shan;leng shan;faber’s fir         NaN          NaN
#
#        is_coniferous  flag
# 32656            1.0   1.0
#        entity_id               sc_name    family  genus species    sub_sp  \
# 32657      32658  Abies fabri minensis  Pinaceae  Abies   fabri  minensis
#
#        common_name range_state  is_tropical  is_coniferous  flag
# 32657  minshan fir         NaN          NaN            1.0   1.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id                          sc_name    family  genus  \
# 19731      19732  Abies nordmanniana equi-trojani  Pinaceae  Abies
#
#             species        sub_sp             common_name range_state  \
# 19731  nordmanniana  equi-trojani  kazdagi fir;trojan fir         NaN
#
#        is_tropical  is_coniferous  flag
# 19731          NaN            1.0   1.0
#        entity_id                          sc_name    family  genus  \
# 33754      33755  Abies nordmanniana nordmanniana  Pinaceae  Abies
#
#             species        sub_sp common_name range_state  is_tropical  \
# 33754  nordmanniana  nordmanniana         NaN         NaN          NaN
#
#        is_coniferous  flag
# 33754            1.0   0.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id                   sc_name    family  genus   species  \
# 22239      22240  Abies sibirica semenovii  Pinaceae  Abies  sibirica
#
#           sub_sp   common_name range_state  is_tropical  is_coniferous  flag
# 22239  semenovii  tienshan fir         NaN          NaN            1.0   0.0
#        entity_id                  sc_name    family  genus   species  \
# 32667      32668  Abies sibirica sibirica  Pinaceae  Abies  sibirica
#
#          sub_sp                                        common_name  \
# 32667  sibirica  西伯利亚冷杉;пихта сибирская;xian bei leng shan;sibe...
#
#       range_state  is_tropical  is_coniferous  flag
# 32667         NaN          NaN            1.0   0.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
#        entity_id                      sc_name       family   genus    species  \
# 18788      18789  Acacia hebeclada chobiensis  Leguminosae  Acacia  hebeclada
#
#            sub_sp common_name range_state  is_tropical  is_coniferous  flag
# 18788  chobiensis         NaN         NaN          NaN            NaN   0.0
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# ...
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# Empty DataFrame
# Columns: [entity_id, sc_name, family, genus, species, sub_sp, common_name, range_state, is_tropical, is_coniferous, flag]
# Index: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-db0d0b86bd60> in <module>()
#      11         (base_df['sub_sp'] == ssp)
#      12     ]
# ---> 13     print (tmp)
#      14     if len(tmp) > 1 :
#      15         print (tmp)
#
# ~/Code/WWF/venv/lib/python3.6/site-packages/pandas/core/base.py in __str__(self)
#      59
#      60         if compat.PY3:
# ---> 61             return self.__unicode__()
#      62         return self.__bytes__()
#      63
#
# ~/Code/WWF/venv/lib/python3.6/site-packages/pandas/core/frame.py in __unicode__(self)
#     661             width = None
#     662         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 663                        line_width=width, show_dimensions=show_dimensions)
#     664
#     665         return buf.getvalue()
#
# ~/Code/WWF/venv/lib/python3.6/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1969                                            max_cols=max_cols,
#    1970                                            show_dimensions=show_dimensions)
# -> 1971         formatter.to_string()
#    1972
#    1973         if buf is None:
#
# ~/Code/WWF/venv/lib/python3.6/site-packages/pandas/io/formats/format.py in to_string(self)
#     605                          .format(name=type(self.frame).__name__,
#     606                          col=pprint_thing(frame.columns),
# --> 607                          idx=pprint_thing(frame.index)))
#     608             text = info_line
#     609         else:
#
# ~/Code/WWF/venv/lib/python3.6/site-packages/pandas/io/formats/printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     215         result = _pprint_seq(thing, _nest_lvl, escape_chars=escape_chars,
#     216                              quote_strings=quote_strings,
# --> 217                              max_seq_items=max_seq_items)
#     218     elif isinstance(thing, compat.string_types) and quote_strings:
#     219         if compat.PY3:
#
# ~/Code/WWF/venv/lib/python3.6/site-packages/pandas/io/formats/printing.py in _pprint_seq(seq, _nest_lvl, max_seq_items, **kwds)
#     107         nitems = max_seq_items or get_option("max_seq_items") or len(seq)
#     108
# --> 109     s = iter(seq)
#     110     r = []
#     111     for i in range(min(nitems, len(seq))):  # handle sets, no slicing
#
# KeyboardInterrupt:
