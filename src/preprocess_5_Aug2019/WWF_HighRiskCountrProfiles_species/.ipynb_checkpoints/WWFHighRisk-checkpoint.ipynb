# %%
import pandas as pd
import textacy
import spacy
nlp = spacy.load('en')
from iso3166 import countries
def get_df():
    file = 'WWF_HighRiskCountryProfiles_Species.xlsx'
    df = pd.read_excel(file)
    return df
df = get_df()

countries = list(df['Country of Origin Risk'])

def process_country_row(sent):
    c_list = sent.replace("," , " , ")
    c_list = c_list.replace('also via', ',')
    c_list = c_list.replace('and via', ',')
    c_list = c_list.replace('all via', ',')
    c_list = c_list.replace(' all', ',')
    c_list = c_list.replace(' also', ',')
    c_list = c_list.replace(' and', ',')
    c_list = c_list.replace(' & ', ',')
    c_list = c_list.replace(' also ', ',')
    c_list = c_list.replace(' via ', ',')
    c_list = c_list.replace('-',' ')
    c_list = textacy.preprocess.normalize_whitespace(c_list)
    c_list = c_list.split('(Note')[0]
    c_list = c_list.split (',')
    
    res_list=[]
    for item in c_list:
        item = item.strip()
        if len(item) < 20 and len (item) > 0 :
            res_list.append(item)
            
    return res_list

# ---------- #
# Create a list of all countries , to clean up
# ---------- #
all_countries = []
for c_list in countries:
    if type(c_list)!= str:
        continue
    res_list = process_country_row(c_list)
    all_countries.extend(res_list)
    
all_countries = list(set(all_countries))    
print ('All countries')
print(all_countries)
print('----')
# Out:
# All countries
# ['Peru', 'Bolivia', 'El Salvador', 'Cameroon', 'Myanmar', 'China', 'Vietnam', 'Brazil', 'DRC', 'Malaysia', 'Solomon Islands', 'Gabon', 'Papua New Guinea', 'Lao DR', 'Panama', 'Indonesia', 'Russia']
# ----

# %%
#  -------------------------------------- #
#  Replace the country names!
#  Manually curated List 
#  Using iso31366 package
#  from iso3166 import countries
#  print(countries.get('us'))
#  for c in countries:
#        print (c)
#  -------------------------------------- #
ref_corr_country_names = {
    'Bolivia' : 'Bolivia, Plurinational State of',
    'Russia' : 'Russian Federation',
    'Lao DR' : "Lao People's Democratic Republic",
    'DRC' : 'Congo, Democratic Republic of the',
    'Vietnam' : "Viet Nam"
}
from iso3166 import countries
replace_dict = {}

for c in all_countries:
    if c not in ref_corr_country_names.keys():
        res = countries.get(c)
    else:
        c_name = ref_corr_country_names[c]
        res = countries.get(c_name)
        
    if res is not None:   
        replace_dict[c] = res.alpha2
    else :
        print ("error")

# %%
# Place the country names back in the Data Frame
# using replace_dict
from iso3166 import countries
for i,row in df.iterrows():
    sent = row['Country of Origin Risk']
    p1 = None 
    p2 = None
    if type(sent) == str :    
        # split on via
        sent = sent.replace(","," , ")
        parts = sent.split(' via ')
        if len(parts) > 1 :
            p1 = process_country_row(parts[0])
            p2 = process_country_row(parts[1])
        else :
            p1 = process_country_row(parts[0])
        
        origins = None
        conduit = None
        if p1 is not None:
            origins = []
        .
        for p in p1 :
                if p in ref_corr_country_names.keys():
                    p = ref_corr_country_names[p]
                origins.append(countries.get(p).alpha2)
            origins = ';'.join(origins)
        if p2 is not None:
            conduit = []
            for p in p2 :
                if p in ref_corr_country_names.keys():
                    p = ref_corr_country_names[p]
                conduit.append(countries.get(p).alpha2)
            conduit = ';'.join(conduit)
    df.loc[i,'origin'] = origins
    df.loc[i,'conduit'] = conduit

# %%
# filter out Columns needed
df = df[['Taxonomic Genus','Species, if applicable','Common Names','origin','conduit']]
df = df.rename(columns ={
    'Taxonomic Genus' : 'genus',
    'Species, if applicable': 'species',
    'Common Names' : 'common_name'
})

# %%
df.head(10)
# Out:
#            genus     species  \
# 0         Shorea         NaN
# 1      Dalbergia         NaN
# 2          Pinus  koraiensis
# 3        Quercus   mongolica
# 4    Pterocarpus         NaN
# 5     Pericopsis         NaN
# 6  Dipterocarpus         NaN
# 7      Swietenia         NaN
# 8      Palaquium         NaN
# 9       Canarium         NaN
#
#                                          common_name          origin conduit
# 0  Meranti, lauan, lawaan, seraya, balau, bangkir...     ID;LA;MM;VN      CN
# 1  Rio, Bahia, Brazilian Rosewood, Sheesham, Pali...  LA;MM;PA;VN;BR      CN
# 2  Pine (126 species names of pines as current, t...              RU      CN
# 3  Oak (There are approximately 600 extant specie...              RU      CN
# 4              padauk, padouk, mukwa, narra, amboyna        LA;MM;VN    None
# 5  African teak, afromosia, afrormosia, satinwood...                      CN
# 6  Keruing (Keruing or Asian mahogany, Gurjan. Mo...     ID;LA;MM;VN    None
# 7  Mahogany. It is usually taken to consist of th...           PA;PE      CN
# 8  Nyatoh. 18 species on the Red List, 15 are end...           PA;PE      CN
# 9  All 18 species of the family are on the Red Li...           PA;PE      CN

# %%
for i, row in df.iterrows():
    print ( row['common_name'])
df.to_excel('WWFHighRisk_intermediate.xlsx')
# Out:
# Meranti, lauan, lawaan, seraya, balau, bangkirai, Philippine mahogany, Balau / Selangan Batu in Myanmar, Marsolok (S. platyclados) in Indonesia
# Rio, Bahia, Brazilian Rosewood, Sheesham, Palisander de Rio Grande, or Jacarandá, Cocobolo, Sua, Indian Rosewood or Sonokeling
# Pine (126 species names of pines as current, together with 35 unresolved species and many more synonyms). P. koraiensis (Korean pine from Russia) is protected, CITES listed. Also "Korean cedar"
# Oak (There are approximately 600 extant species of oaks. The common name "oak" may also appear in the names of species in related genera, notably Lithocarpus.)
# padauk, padouk, mukwa, narra, amboyna
# African teak, afromosia, afrormosia, satinwood, yellow satinwood
# Keruing (Keruing or Asian mahogany, Gurjan. More than half of the species are on the Red List as critically endangered or endangered.
# Mahogany. It is usually taken to consist of three species, geographically separated. The three species are poorly defined biologically, in part because they hybridize freely when grown in proximity. In Panama, Swietenia macrophylla
# Nyatoh. 18 species on the Red List, 15 are endangered or vulnerable. Palaquium is a genus of about 120 species of trees in the Sapotaceae family.
# All 18 species of the family are on the Red List, with 12 endangered or vulnerable
# Ochoó
# Tajibo, and Ipê-roxo
# Roble
# Morado
# Spanish cedar (CITES listed)
# Tarara
# Jatobá, Paquió
# Hoja de Yuca/kapok, Lupula
# Ayous
# Iroko
# Sapele mahogany (IUCN lists as Vulnerable)
# Bilinga (IUCN lists as Vulnerable)
# Bubinga (IUCN lists as Vulnerable), Kevazingo
# Cativo
# Abarco,  Colombian mahogany
# Kapur
# Ulin or Borneo ironwood
# Ramin (Listed on CITES Appendix II)
# Afzelia
# Pyinkado
# Merawan
# Merbau (I. palembanic in Malaysia)
# Mersawa
# Hinoki cypress
# Chengal
# Teak
# Sepetir
# Purple heart
# Fiddlewood
# Cumarú, Brazilian teak, Almendrillo
# Estoraque
# Manchurian ash
# Amur linden & Manchurian linden
# Japanese elm
# Lim
# Araucária
# Native brazilwood/pernambuco
# Maçaranduba
# Wengué, Wenge
# Okoume
# Moabi
# Himalayan yew, Japanese yew, Chinese yew
# Taun
# Bintangor
# nan
# nan
# Guatemalan Fir, Mexican Fir
# agarwood, eaglewood, aloewood, agar, oud, oudh
# monkey puzzle tree, Chilean pine
# holy wood, verawood, lignum vitae, Paraguay lignum vitae, Argentine lignum vitae, guaiac, guaiac wood
# ebony
# almendro, tonka bean tree
# Patagonian cypress, Chilean false larch
# sonora guaiacum, lignum-vitae, pockwood, wood of life, tree of life, ironwood
# East African sandalwood
# Guaitecas cypress, Chilean cedar, Patagonian cypress, Patagonian pilgerodendron
# platymiscium
# brown pine, black pine podocarp, Parlatore’s podocarp, yellow wood
# African cherry, African stinkwood, bitter almond, blackwood, ironwood, Pygeum africanum, red stinkwood, red strinkhout
# agaru, red sanders, red sandalwood, sandalwood, saunderswood
